# %%
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, query_engine, StorageContext, load_index_from_storage
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core.memory import Memory
from chromadb.utils.embedding_functions import OllamaEmbeddingFunction
from core.settings import CHROMA_PATH, llm, embed_model, STORAGE_PATH
import chromadb,os
from llama_index.core.storage.chat_store import SimpleChatStore
from llama_index.core.retrievers import VectorIndexRetriever
from services.get_index_service import get_index
from db.chroma_client import get_vector_db_client
from services.documents_service import get_ref_doc_idx, get_storage_context

# %%
from services.ingest_service import build_ingestion_pipeline
# Out:
# c:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validate_default' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'validate_default' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
collection = get_vector_db_client().get_collection("dep")
vector_store = ChromaVectorStore(chroma_collection=collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store)
index = VectorStoreIndex.from_vector_store(vector_store=vector_store)

# %%
client = get_vector_db_client()
collection = client.get_collection(name="dep")
metadatas  = collection.get(
        where={"file_name": "HiveWorx_HR_Policy_Manual.pdf"},
    include=["metadatas"] 
    ).get("metadatas")

# %%
len(metadatas)
# Out:
# 391

# %%
metadatas[0].get("file_name")
# Out:
# 'HiveWorx_HR_Policy_Manual.pdf'

# %%
files = set()
for metadata in metadatas:
    files.add(metadata.get("file_name"))

files
# Out:
# {'HiveWorx_HR_Policy_Manual.pdf'}

# %%
docstore = index.storage_context.docstore

# %%
vectorstore= index.storage_context.vector_store

# %%
len(docstore.docs)
# Out:
# 0

# %%
docstore.docs.keys()
# Out:
# dict_keys([])

# %%
docs = SimpleDirectoryReader(input_files=[r"C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf"]).load_data()

# %%
docs[0]
# Out:
# Document(id_='ed5e240b-398d-4bd0-8be9-f2ff2162efeb', embedding=None, metadata={'page_label': '1', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'file_path': 'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf', 'file_type': 'application/pdf', 'file_size': 1048607, 'creation_date': '2025-10-27', 'last_modified_date': '2025-10-28'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 1 of 35 \n \n  \n  \n \n \nHUMAN RESOURCE POLICY MANUAL \n                                      Islamabad Office \n                                 Effective July, 2019 \n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')

# %%
pipeline = build_ingestion_pipeline(doc_store=index.storage_context.docstore, vector_store=index.storage_context.vector_store)

# %%
nodes = pipeline.run(documents =docs)

# %%
nodes[0]
# Out:
# TextNode(id_='fa829b1a-d8a2-44b5-8a02-c716da168ec3', embedding=None, metadata={'page_label': '1', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'file_path': 'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf', 'file_type': 'application/pdf', 'file_size': 1048607, 'creation_date': '2025-10-27', 'last_modified_date': '2025-10-28'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'ceo', 'manager', 'developer', 'department'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'ceo', 'manager', 'developer', 'department'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='ed5e240b-398d-4bd0-8be9-f2ff2162efeb', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '1', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'file_path': 'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf', 'file_type': 'application/pdf', 'file_size': 1048607, 'creation_date': '2025-10-27', 'last_modified_date': '2025-10-28'}, hash='d4ee5ff8e4eeee171b1dc8f96e097cfdb45f517d673677c2b2511afd6e4f3073')}, metadata_template='{key}: {value}', metadata_separator='\n', text='HR POLICY MANUAL     \nPage 1 of 35 \n \n  \n  \n \n \nHUMAN RESOURCE POLICY MANUAL \n                                      Islamabad Office \n                                 Effective July, 2019', mimetype='text/plain', start_char_idx=92, end_char_idx=279, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}')

# %%
index.insert_nodes(nodes=nodes)

# %%
len(index.storage_context.docstore.docs)
# Out:
# 0

# %%
storage_context.persist()

# %%
docstore = index.storage_context.docstore

# %%
for doc in docstore.docs.items():
    print(doc[0])
    print(doc[1].metadata)
    print(doc[1].doc_id)
    print(doc[1].id_)
    break
# Out:
# 4131da9b-7df5-4b82-8615-594f40b095ca
# {'page_label': '1', 'file_name': '100-English-Short-Stories.pdf', 'file_path': 'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf', 'file_type': 'application/pdf', 'file_size': 2037873, 'creation_date': '2025-10-27', 'last_modified_date': '2025-10-28'}
# 4131da9b-7df5-4b82-8615-594f40b095ca
# 4131da9b-7df5-4b82-8615-594f40b095ca

# %%
index.delete(doc_id="4131da9b-7df5-4b82-8615-594f40b095ca", delete_from_docstore=True)
# Out:
# 2025-10-28 04:32:29,551 - WARNING - delete() is now deprecated, please refer to delete_ref_doc() to delete ingested documents+nodes or delete_nodes to delete a list of nodes.Use adelete_ref_docs() for an asynchronous implementation

# %%
storage_context.persist()

# %%
docstore = index.storage_context.docstore

# %%
docstore.get_document("4131da9b-7df5-4b82-8615-594f40b095ca")
# Out:
# Document(id_='4131da9b-7df5-4b82-8615-594f40b095ca', embedding=None, metadata={'page_label': '1', 'file_name': '100-English-Short-Stories.pdf', 'file_path': 'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf', 'file_type': 'application/pdf', 'file_size': 2037873, 'creation_date': '2025-10-27', 'last_modified_date': '2025-10-28'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=None, image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')

# %%
###################working from here #############################3333333

# %%
ref_doc_idx = get_ref_doc_idx(department="dep",doc_name="ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf")
# Out:
# got collection already created.
# after initializing vector store
# before storage_context initialization
# from withing the create or get storage path:dep
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep
# from withing the create or get storage path:dep
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep\docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep\index_store.json.
# storage_context from path
# before returning storage_context......................
# 375

# %%
len(ref_doc_idx)
# Out:
# 0

# %%
storage_context = get_storage_context(department="dep")
docstore = storage_context.docstore
print(len(docstore.docs))

ref_doc_ids = set()

for node_id, node in docstore.docs.items():
    print(node_id)
    print(node.doc_id)
    metadata = node.metadata or {}
    print(metadata)
    if metadata.get("file_name") =="ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf":
        ref_doc_id = metadata.get("ref_doc_id")
        if ref_doc_id:
            ref_doc_ids.add(ref_doc_id)
# Out:
# got collection already created.
# after initializing vector store
# before storage_context initialization
# from withing the create or get storage path:dep
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep
# from withing the create or get storage path:dep
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep\docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep\index_store.json.
# storage_context from path
# before returning storage_context......................
# 375
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_0
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_0
# {'page_label': '1', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_1
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_1
# {'page_label': '2', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_2
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_2
# {'page_label': '3', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_3
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_3
# {'page_label': '4', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_4
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_4
# {'page_label': '5', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_5
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_5
# {'page_label': '6', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_6
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_6
# {'page_label': '7', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_7
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_7
# {'page_label': '8', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_8
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_8
# {'page_label': '9', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_9
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_9
# {'page_label': '10', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_10
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_10
# {'page_label': '11', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_11
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_11
# {'page_label': '12', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_12
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_12
# {'page_label': '13', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_13
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_13
# {'page_label': '14', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_14
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_14
# {'page_label': '15', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_15
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_15
# {'page_label': '16', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_16
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_16
# {'page_label': '17', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_17
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_17
# {'page_label': '18', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_18
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_18
# {'page_label': '19', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_19
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_19
# {'page_label': '20', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_20
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_20
# {'page_label': '21', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_21
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_21
# {'page_label': '22', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_22
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_22
# {'page_label': '23', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_23
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_23
# {'page_label': '24', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_24
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_24
# {'page_label': '25', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_25
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_25
# {'page_label': '26', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_26
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_26
# {'page_label': '27', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_27
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_27
# {'page_label': '28', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_28
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_28
# {'page_label': '29', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_29
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_29
# {'page_label': '30', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_30
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_30
# {'page_label': '31', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_31
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_31
# {'page_label': '32', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_32
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_32
# {'page_label': '33', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_33
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_33
# {'page_label': '34', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_34
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_34
# {'page_label': '35', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_0
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_0
# {'page_label': '1', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_1
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_1
# {'page_label': '2', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_2
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_2
# {'page_label': '3', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_3
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_3
# {'page_label': '4', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_4
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_4
# {'page_label': '5', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_5
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_5
# {'page_label': '6', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_6
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_6
# {'page_label': '7', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_7
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_7
# {'page_label': '8', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_8
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_8
# {'page_label': '9', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_9
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_9
# {'page_label': '10', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_10
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_10
# {'page_label': '11', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_11
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_11
# {'page_label': '12', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_12
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_12
# {'page_label': '13', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_13
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_13
# {'page_label': '14', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_14
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_14
# {'page_label': '15', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_15
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_15
# {'page_label': '16', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_16
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_16
# {'page_label': '17', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_17
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_17
# {'page_label': '18', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_18
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_18
# {'page_label': '19', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_19
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_19
# {'page_label': '20', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_20
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_20
# {'page_label': '21', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_21
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_21
# {'page_label': '22', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_22
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_22
# {'page_label': '23', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_23
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_23
# {'page_label': '24', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_24
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_24
# {'page_label': '25', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_25
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_25
# {'page_label': '26', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_26
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_26
# {'page_label': '27', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_27
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_27
# {'page_label': '28', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_28
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_28
# {'page_label': '29', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_29
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_29
# {'page_label': '30', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_30
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_30
# {'page_label': '31', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_31
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_31
# {'page_label': '32', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_32
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_32
# {'page_label': '33', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_33
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_33
# {'page_label': '34', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_34
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_34
# {'page_label': '35', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_35
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_35
# {'page_label': '36', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_36
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_36
# {'page_label': '37', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_37
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_37
# {'page_label': '38', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_38
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_38
# {'page_label': '39', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_39
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_39
# {'page_label': '40', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_40
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_40
# {'page_label': '41', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_41
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_41
# {'page_label': '42', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_42
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_42
# {'page_label': '43', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_43
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_43
# {'page_label': '44', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_44
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_44
# {'page_label': '45', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_45
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_45
# {'page_label': '46', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_46
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_46
# {'page_label': '47', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_47
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_47
# {'page_label': '48', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_48
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_48
# {'page_label': '49', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_49
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_49
# {'page_label': '50', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_50
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_50
# {'page_label': '51', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_51
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_51
# {'page_label': '52', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_52
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_52
# {'page_label': '53', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_53
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_53
# {'page_label': '54', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_54
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_54
# {'page_label': '55', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_55
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_55
# {'page_label': '56', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_56
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_56
# {'page_label': '57', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_57
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_57
# {'page_label': '58', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_58
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_58
# {'page_label': '59', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_59
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_59
# {'page_label': '60', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_60
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_60
# {'page_label': '61', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_61
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_61
# {'page_label': '62', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_62
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_62
# {'page_label': '63', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_63
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_63
# {'page_label': '64', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_64
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_64
# {'page_label': '65', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_65
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_65
# {'page_label': '66', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_66
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_66
# {'page_label': '67', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_67
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_67
# {'page_label': '68', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_68
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_68
# {'page_label': '69', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_69
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_69
# {'page_label': '70', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_70
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_70
# {'page_label': '71', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_71
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_71
# {'page_label': '72', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_72
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_72
# {'page_label': '73', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_73
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_73
# {'page_label': '74', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_74
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_74
# {'page_label': '75', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_75
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_75
# {'page_label': '76', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_76
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_76
# {'page_label': '77', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_77
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_77
# {'page_label': '78', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_78
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_78
# {'page_label': '79', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_79
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_79
# {'page_label': '80', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_80
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_80
# {'page_label': '81', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_81
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_81
# {'page_label': '82', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_82
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_82
# {'page_label': '83', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_83
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_83
# {'page_label': '84', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_84
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_84
# {'page_label': '85', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_85
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_85
# {'page_label': '86', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_86
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_86
# {'page_label': '87', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_87
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_87
# {'page_label': '88', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_88
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_88
# {'page_label': '89', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_89
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_89
# {'page_label': '90', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_90
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_90
# {'page_label': '91', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_91
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_91
# {'page_label': '92', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_92
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_92
# {'page_label': '93', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_93
# ...
# {'page_label': '85', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_85
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_85
# {'page_label': '86', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_86
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_86
# {'page_label': '87', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_87
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_87
# {'page_label': '88', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_88
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_88
# {'page_label': '89', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_89
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_89
# {'page_label': '90', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_90
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_90
# {'page_label': '91', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_91
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_91
# {'page_label': '92', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_92
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_92
# {'page_label': '93', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_93
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_93
# {'page_label': '94', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_94
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_94
# {'page_label': '95', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_95
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_95
# {'page_label': '96', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_96
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_96
# {'page_label': '97', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_97
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_97
# {'page_label': '98', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_98
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_98
# {'page_label': '99', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_99
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_99
# {'page_label': '100', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_100
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_100
# {'page_label': '101', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_101
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_101
# {'page_label': '102', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_102
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_102
# {'page_label': '103', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_103
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_103
# {'page_label': '104', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_104
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_104
# {'page_label': '105', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_105
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_105
# {'page_label': '106', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_106
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_106
# {'page_label': '107', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_107
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_107
# {'page_label': '108', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_108
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_108
# {'page_label': '109', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_109
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_109
# {'page_label': '110', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_110
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_110
# {'page_label': '111', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_111
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_111
# {'page_label': '112', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_112
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_112
# {'page_label': '113', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_113
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_113
# {'page_label': '114', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_114
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_114
# {'page_label': '115', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_115
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_115
# {'page_label': '116', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_116
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_116
# {'page_label': '117', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_117
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_117
# {'page_label': '118', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_118
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_118
# {'page_label': '119', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_119
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_119
# {'page_label': '120', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_120
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_120
# {'page_label': '121', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_121
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_121
# {'page_label': '122', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_122
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_122
# {'page_label': '123', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_123
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_123
# {'page_label': '124', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_124
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_124
# {'page_label': '125', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_125
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_125
# {'page_label': '126', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_126
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_126
# {'page_label': '127', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_127
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_127
# {'page_label': '128', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_128
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_128
# {'page_label': '129', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_129
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_129
# {'page_label': '130', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_130
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_130
# {'page_label': '131', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_131
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_131
# {'page_label': '132', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_132
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_132
# {'page_label': '133', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_133
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\100-English-Short-Stories.pdf_part_133
# {'page_label': '134', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}

# %%
index = storage_context.index_store
type(index)
# Out:
# llama_index.core.storage.index_store.simple_index_store.SimpleIndexStore

# %%
for doc in docstore.docs:
    print(doc)
    break
# Out:
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\HiveWorx_HR_Policy_Manual.pdf_part_0

# %%
len(ref_doc_ids)
# Out:
# 0

# %%
from services.documents_service import get_storage_context

# %%
doc_ids = get_doc_idx(department="dep",doc_name="HiveWorx_HR_Policy_Manual.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 doc_ids = get_doc_idx(department="dep",doc_name="HiveWorx_HR_Policy_Manual.pdf")
#
# NameError: name 'get_doc_idx' is not defined

# %%
storage_context = get_storage_context(department="dep")
docstore = storage_context.docstore
# Out:
# got collection already created.
# after initializing vector store
# before storage_context initialization
# from withing the create or get storage path:dep
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep
# from withing the create or get storage path:dep
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep\docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep\index_store.json.
# storage_context from path
# before returning storage_context......................

# %%
len(docstore.docs)
# Out:
# 375

# %%
docstore.get_all_ref_doc_info()
# Out:
# {}

# %%
docstore._ref_doc_collection
# Out:
# 'docstore/ref_doc_info'

# %%
kv = docstore._kvstore

# %%
storage

# %%
storage_context.docstore.get_all_ref_doc_info()
# Out:
# {}

# %%
ref_docs
# Out:
# {}

# %%
for doc in docstore:
    doc = doc
    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 for doc in docstore:
#       2     doc = doc
#       3     break
#
# TypeError: 'SimpleDocumentStore' object is not iterable

# %%
doc
# Out:
# 'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_0'

# %%
docstore.docs
# Out:
# {'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_0': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_0', embedding=None, metadata={'page_label': '1', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 1 of 35 \n \n  \n  \n \n \nHUMAN RESOURCE POLICY MANUAL \n                                      Islamabad Office \n                                 Effective July, 2019 \n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_1': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_1', embedding=None, metadata={'page_label': '2', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 2 of 35 \n \n \n1 GENERAL ............................................................................................................................................................ 4 \n \n2 DEFINITIONS ...................................................................................................................................................... 5 \n2.1 Office ........................................................................................................................................................... 5 \n2.2 The Chief Executive Officer (CEO) ............................................................................................................. 5 \n2.3 The Management .......................................................................................................................................... 5 \n2.4  The Employees ............................................................................................................................................. 5 \n2.5  The Permanent Employees ……………………………………………………………………...…………5 \n2.6  The Service .................................................................................................................................................. 5 \n2.7        The Experience ............................................................................................................................................. 5 \n \n3 APPOINTMENT ................................................................................................................................................... 6 \n3.1 Appointment................................................................................................................................................. 6 \n3.2 Probation period ........................................................................................................................................... 6 \n3.3 Completion of probationary period .............................................................................................................. 6 \n3.4         Non-disclosure agreement ……………………………………………………………………...…...……..6 \n3.5 Assignment................................................................................................................................................... 6 \n \n4 BANDS, DESIGNATIONS AND CLASSES ....................................................................................................... 7 \n4.1 Development ................................................................................................................................................ 7 \n4.2 Operations .................................................................................................................................................... 7 \n4.3 Support ......................................................................................................................................................... 8 \n \n5 RESIGNATION ........................................................................................................... ...
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_2': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_2', embedding=None, metadata={'page_label': '3', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 3 of 35 \n \n \n \n11.3 Bonuses ...................................................................................................................................................... 20 \n11.4 Overtime .................................................................................................................................................... 20 \n    11.5    Benefits ...................................................................................................................................................... 21 \n11.6    Leaves ........................................................................................................................................................ 24 \n \n12  EMPLOYEE ASSISTANCE PROGRAM ............................................................................................................ 28 \n  12.1   Personal Loan .............................................................................................................................................. 28 \n \n13 EXTRA CURRICULAR ACTIVITIES ................................................................................................................. 29 \n13.1   Table Tennis .................................................................................................................................................. 29 \n13.2   Cricket ........................................................................................................................................................... 29 \n13.3   A Day Out ...................................................................................................................................................... 29 \n13.4   Annual Dinner ............................................................................................................................................... 29 \n13.5   Other Events .................................................................................................................................................. 30 \n \n14 TRAVELLING ON OFFICIAL BUSINESS.......................................................................................................... 31 \n14.1   Scope ............................................................................................................................................................. 31 \n14.2   Policy Guidelines ........................................................................................................................................... 31 \n14.3   Per Diem Policy ............................................................................................................................................. 32 \n14.4   Expense Coverage for Traveling ................................................................................................................... 33 \n \n \n \n \n \n \n \n \n \n \n \n  \n \n \n \n \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_3': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_3', embedding=None, metadata={'page_label': '4', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 4 of 35 \n \n \n1. The following rules set forth the terms and conditions of employment for the \nEmployees of HiveWorx (Pvt.) Ltd. (HiveWorx) hereunder referred to  as the \n“Rules” \n \n2. The Rules shall be effective from July 01, 2019 superseding the previous ones unless \notherwise notified by the Management. \n \n3. These rules are subject to additions, alterations and modifications from time to time \nat the sole discretion of the Management. \n \n \n \n \n \n \n \n \n \n \n \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_4': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_4', embedding=None, metadata={'page_label': '5', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 5 of 35 \n \n \n2.1 Office \n           Office means the Offices of HiveWorx, including Islamabad Office:  \n           2nd Floor, Darvesh Plaza, Opp. Gate-1, DHA phase-II, Islamabad, Pakistan. \n2.2 The Chief Executive Officer (CEO) \nThe Chief Executive Officer (CEO) means the Chief Representative deputed by the \nBoard of Directors (BOD) of Company. Under CEO, the Directors and Managers of \nCompany are the members of The Management. \n2.3 The Management \nManagement means CEO or Authorized Per son who is authorized by CEO or BOD to \nperform or execute related management jobs including the Country Managers and Line \nManagers of all the offices and departments. \n2.4  The Employees \nEmployees mean any person or persons employed on permanent or probationary period \nand future employees of such categories. Employee shall not engage him/herself in any \nother organization’s business activity nor shall become an employee of any other \norganization without written approval of the Management. \n2.5  The Permanent Employees \nPermanent employees mean any person employed on full time service. A permanent           \nemployee is an employee engaged on a permanent basis. \n2.6  The Service \nService means the duration of employment starting from confirmation. However, \ndecision rests at sole discretion of Management whether to consider the probation period \nor not. Consideration of probation period may vary on case -to-case basis. Training or \ninternship period of any employee would not be considered as service period. \n2.7  The Experience \nExperience means the relevant experience, which does not include Probation time -\nperiod, Training & Internship.  \n \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_5': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_5', embedding=None, metadata={'page_label': '6', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 6 of 35 \n \n \n  \n3.1  Appointment \n The appointing/employing authority may be CEO and the Management. The right of \nselection procedure may be at the sole discretion of the departmental head or Director. \n3.2  Probation period \nThe normal initial probation period may be 3 months but may vary depending upon the \ntype and performance of an employee. Probation period stipulated in the letter of \nappointment may be extended if considered necessary by The Management. The services \nof an employee are subject to termination without notice and without assigning any reason, \nduring the probationary period. \n3.3  Completion of probationary period \nAfter successfully completing the probationary period, the employee may be inducted into \nregular cadre of the company and his/her employment shall be subject to the terms and \nconditions specified in the confirmation letter. It is at the sole discretion of department al \nhead or director to include or exclude an employee’s probation period with service period. \nUpon completion, salary may also be revised. \n3.4  Non-disclosure agreement  \nEvery employee is bound to sign an employee non-disclosure form upon employment. By     \nsigning this document employee agrees to the terms and conditions  regarding \nconfidentiality.             \n3.5 Assignment \nAll employees may be required to serve in any office / Client site worldwide keeping in \nview the business exigencies and their service s may be assigned to any of the sister \nconcerns, subsidiaries and associated companies of HiveWorx. \n \n \n \n \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_6': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_6', embedding=None, metadata={'page_label': '7', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 7 of 35 \n \n \n \n4.1 Development \nExperience \n(Minimum) Band Integration Services Business Intelligence \nSoftware \nDevelopment \n0 T3 Jr. Consultant Jr. Consultant Jr. Software Engineer \n  (Integration Services) (Business Intelligence)  \n1 T4 Consultant Consultant Software Engineer \n  (Integration Services) (Business Intelligence)  \n3 T5 Sr. Consultant Sr. Consultant Sr. Software Engineer \n  (Integration Services) (Business Intelligence)  \n5 T6 Team Lead Team Lead Team Lead \n  (Integration Services) (Business Intelligence) (Product Development) \n7 T7 Project Lead Project Lead Project Lead \n10 T8 Technical Manager Technical Manager Technical Manager \n12 T9 Project Manager Project Manager Project Manager \n14 T10 Program Manager Program Manager Program Manager \n16 T11 Director Director Director \n4.2 Operations \nExperience \n(Minimum) Band PMO Integration Services \nBusiness \nIntelligence \nSoftware \nDevelopment \n 0   O3   Assistant Project   Jr. Consultant   Jr. Consultant   Jr. Software  \n       Coordinator (PM)   (Integration Services)   (Business Intelligence)   Engineer  \n1   O4  Project  Consultant  Consultant  \nSoftware \nEngineer \n       Coordinator (PM)  (Integration Services)  (Business Intelligence)    \n 3   O5   Sr. Project   Sr. Consultant   Sr. Consultant   Sr. Software  \n       Coordinator (PM)   (Integration Services)   (Business Intelligence)   Engineer  \n5   O6  Assistant Manager  Team Lead  Team Lead  Team Lead \n       (PM)  (Integration Services)  (Business Intelligence)  \n(Software \nDevelopment) \n 7   O7   Manager (PM)   Project Lead   Project Lead   Project Lead  \n10   O8  Sr. Manager (PM)  Technical Manager  Technical Manager  \nTechnical \nManager \n 12   O9   Project Manager   Project Manager   Project Manager   \nProject \nManager  \n14   O10  Program Manager  Program Manager  Program Manager  \nProgram \nManager \n 16   O11   Director   Director   Director   Director  \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_7': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_7', embedding=None, metadata={'page_label': '8', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 8 of 35 \n \n \n4.3 Support \nExperience \n(Minimum) Band HR Finance & Accounts Admin \n 0  S3 Jr. Assistant (HR) Jr. Assistant (F&A) Jr. Assistant (Admin) \n1  S4 Assistant (HR) Assistant (F&A) Assistant (Admin) \n 3  S5 Executive (HR) Executive (F& A) Executive (Admin) \n5  S6 Assistant Manager (HR) Assistant Manager (F& A) \nAssistant Manager \n(Admin) \n 7  S7 Manager (HR) Manager (F& A) Manager (Admin) \n10  S8 Sr. Manager (HR) Sr. Manager (F& A) Sr. Manager (Admin) \n 12  S9 General Manager (HR) CFO \nGeneral Manager \n(Admin) \n14  S10 Deputy Director Deputy Director Deputy Director \n 16  S11 Director Director Director \n \n \n  \n \n \n \n   \nBands will be further divided into three Classes namely A, B & C w.r.t. seniority with T11A the \nsenior most category in Development. \n \nNote: \n   \n   \n  \nMinimum Required Experience is based on 16 Years of education. Obtaining higher education \ndegree may further reduce the requirement. \n     \n       \n \n \n \n \n \n \n \n \n \n \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_8': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_8', embedding=None, metadata={'page_label': '9', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 9 of 35 \n \n \n \nAn employee may leave service on submitting to HR advance notice in writing stating reasons \nthereof or otherwise stated in the job contract and subject to his/her final clearance by competent \nauthorities. An employee may serve to HiveWorx Management a minimum of one month’s \nadvance notice or as per his signed job contract. When an advance notice is accepted by the \nManagement, the employee may be required to hand over the charge of his/her work to the \nperson appointed by the Management. It is at the sole discretion of Management to terminate \nan employee without serving notice period.  \n \n1. Employee on notice period may be barred from all sorts of leave. In case of leave on \nnotice period, notice period may be extended.  \n \n2. Employee is bound to confer all the knowledge and pending tasks within one month of \nnotice period. In case of failure in handing over the knowledge and completi on of \npending tasks, employee is bound to continue notice period beyond stipulated time \nperiod unless complete knowledge is transferred and all pending tasks are completed.  \n \n3. Before leaving service an employee is bound to handover all assets owned by HiveWorx \nto HR. The final dues may be processed after submission of assets. \n \n4. If an employee continues to stay absent on notice period, he/she will be considered on \nleave without pay. \n \n \n \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_9': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_9', embedding=None, metadata={'page_label': '10', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 10 of 35 \n \n \n \n6.1  Retirement/Redundancy \nIn the event of general retirem ent/redundancy, the Management may relieve the \nemployees after giving a notice as per his signed contract or one month’s gross salary in \nlieu thereof. The Management would be the sole judge to retrench any employee \nirrespective of the length of service. \n6.2  Misconduct \nThe management reserves the right of terminating an employee who is not abiding by the \nrules and regulations set by the company. In such case, employee may be served by either \na Show Cause Notice seeking his point of view, a direct Warning Le tter or Severe \nReprimand depending on the severity of misconduct. Management reserves the right to \nDemote or Terminate an Employee based on Warning Letter or Severe Reprimand. An \nemployee may not be eligible to claim any benefits if terminated on misconduct.  \n6.3  Closure or Transfer of business / office \nIn the event, Company closes down any Office, all the employees of that office may stand \nterminated after giving one month’s prior notice or one month’s gross salary in lieu of \nnotice or in case the business is transferred to another company, the office may relieve all \nthe employees. \n \n \n \n \n \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_10': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_10', embedding=None, metadata={'page_label': '11', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 11 of 35 \n \n \n \nMBO (Management by Objectives) sheet to be used for Performance Appraisal of all staff \nthrough individual meetings with the management, scheduled as under: - \n \n         Setting the Objectives: First half of January  \n         Mid-Year Review: End-June \n         End of Term Review: End-Dec \n \nPrecise Objectives, targets and expectations should be mentioned specifically in the sheet \nagreed by the employee s and then their performance may be judged  accordingly. Employee’s \nannual, bi-annual appraisals, increment, bonus, promotion or otherwise shall be decided by the \ncompetent authority on the basis of their MBOs. \n \n \n \n \n \n \n \n \n \n \n \n \n \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_11': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_11', embedding=None, metadata={'page_label': '12', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 12 of 35 \n \n \n \n1. All permanent Employees contribute 5% of their basic salary as provident fund. \n \n2. Company may contribute 5% of every permanent employee’s basic salary as         \nprovident fund. \n \n3. If an employee decides to discontinue his services with Company within 1 year, he may \nbe paid back his 5% contribution only and he will not be eligible for Company’s 5% \ncontribution. \n \n4. Employees with 13 months or more service may be paid 5% of their contribution along \nwith 5% company’s contribution at the end of their service. \n \n5. Provident fund calculation will be made at the completion of every month. \n \n \n \nEmployees who were eligible for gratuity after 3 years of service according to previous \npolicy, may not contribute 5% of their basic salary until the gratuity amount is exhausted. \nProvident fund amount may be taken from their amount of gratuity 5% on monthly basis. \nHowever, if the already eligible employees (before 01 -July-2019) demand encashment of \ngratuity, the same can be paid to them. In such case, they will be contributing for provident \nfund as rest of the employees.  \n  ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_12': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_12', embedding=None, metadata={'page_label': '13', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 13 of 35 \n \n \n \n9.1 Code of Conduct \n1. Keep your workstation clean and organized.  \n2. Eatables are not advisable in working area. Employees are directed to avoid eating \nat workstation, unless inevitable.  \n3. Do not glance into other’s workstation. Knock before entering into any resource’s/ \nroom cabin. \n4. Take care of your tone and pitch while speaking. Mind other employees are sitting \naround you as well.  \n5. Do not shout from your desk. If you do not hav e access to the extension phone, \nwalk to the other person’s desk.  \n6. Smoking at the workstation is an offence. Always use the designated Smoking \nareas.  \n7. Adopt professional attitude at work.  \n8. Put your cell phone on the silent or vibrating mode at the workplace.  \n9. Seek permission before using anyone else’s notepads, registers or files. \n10. Stay away from politics/negative behavior and grouping at the workplace.  \n11. Do not pass lewd comments to any of your fellow workers. Do no t criticize or \nbully any of your colleagues.  \n12. Respect your fellow workers and try to help them. \n13. It is not allowed  to share confidential  data with external parties or irrelevant \ncolleagues.  \n14. Employee is liable to follow the instructions dispatched by the management from \ntime to time without any concern. \n \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_13': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_13', embedding=None, metadata={'page_label': '14', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 14 of 35 \n \n9.2  Dress Code \n                   Male Employees \n1. Male employees ideally should combine a simple dress with Pants/trousers. \nColors should be well-coordinated.   \n2. The shirt should be properly tucked into the trouser  for the professional look. \nPrefer full sleeve shirts at workplace. Do not roll up your sleeves.  \n3. Use a mild perfume or deodorant. \n4. Shorts and/or sleeveless shirts are not allowed. \n                    Female Employees \n1. Females should not wear revealing clothes to work . Avoid wearing outfits, \nwhich expose much of your body parts. Don’t wear too tight or loose clothes.  \n2. Do not wear heavy jewelry at work. Avoid wearing heavy makeup.  \n3. Avoid wearing sharp pointed heels at work.  \n4. Use a mild perfume or deodorant. \n9.3  Company Assets  \n1. Employee may be provided with the official assets suc h as laptop, mobile, \ninternet devices etc. and protection of these devices will be employee’s \nresponsibility. If any of these devices gets damaged or lost/stolen employee may \nbe responsible for the repair/maintenance/recovery. However, if the damage \noccurs at office premises/official trips that does not involve any negligence of \nemployee, in that case company may bear the cost of damage. \n2. Official assets are for official use only. Employees are not allowed to use it for \nany personal reasons i.e. keeping pers onal files of any sort in official laptop or \nuse of internet for any personal purposes. In case of negligence, penalty may be \nimposed.  \n \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_14': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_14', embedding=None, metadata={'page_label': '15', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 15 of 35 \n \n3. Employee is bound to hand over all the official assets to the company on his/her \nlast serving day. There may be no lev erage given to the person for holding \nofficial assets after notice period. \n9.4  Working hours \n    Regular Timings \n \n     Working hours and Lunchtime shall be observed as under: \n \n  Ramadan Timing         \nDESCRIPTION  START TIME END TIME \nMONDAY TO THURSDAY 09:00 16:00 hours \nFRIDAY 09:00 13:00 hours \n \nEmployee may avail maximum leverage of late com ing till 9:30am  in case of emergency. \nHowever, habitual late coming may not be accepted. Saturday & Sunday are weekly closed. \nThe Management may alter/adjust working hours of any employee at any time to suit the \nexigencies of business and the requirement o f the law so as not to exceed nine (9) hours in a \nday and forty -five (45) hours in a week. However, if employee is required to serve beyond \nworking hours or on working day, employee is bound to work to the fulfillment of the task and \nin return, company may  compensate him in the nature of overtime or a day off or giving half \nday in next week. The deficiency of an Employee not completing weekly 45 hours may be \nadjusted with equivalent leaves.    \n9.5  Holidays \n1. All gazetted national holidays of Central Governme nt under the Labor Laws and days \noff declared by the office may be observed as holidays. \n \n \nDESCRIPTION  START TIME END TIME \nMONDAY TO FRIDAY 09:00 hours 18:00 hours \nLUNCH BREAK 13:00 hours 14:00 hours \nFRIDAY LUNCH/PRAYER \nBREAK \n13:00 hours 14:30 hours ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_15': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_15', embedding=None, metadata={'page_label': '16', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 16 of 35 \n \n2. When an employee works on a holiday, the Management may allow him a day/ half day \nor hours off in lieu. P aying overtime allowance rests at the discretion of the \nManagement. \n9.6 IN/OUT Register \nIn case during office hours any employee wants to go out of the office premises for any reason, \nhe has to fill in the IN/OUT register stating the reason of going out and expected time of return, \nthat also includes the lunch break. On his return, he is required to update the same record w ith \nhis actual time of return.  \n9.7  Educational / Professional Engagement \n \nDuring office hours, an employee may not be engaged in any Educational / Professional \nengagement other than assigned by the company. If any employee is willing to enhance his \neducation after working hours, he may take a consent from company. However, incase company \nrequires an employee to sit late or work on holidays for any official engagement, preference \nshould always be given to the company’s tasks. \n \nIf an employee is already engaged in any unofficial Educational/professional activity at the time \nof the enforcement date of this policy, he/she is bound to immediately inform HR. If a resource \nis engaged in any such activity before hiring in company, the same must be informed at the time \nof hiring. \n \n \n \n \n \n \n \n \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_16': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_16', embedding=None, metadata={'page_label': '17', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 17 of 35 \n \n \n \n10.1 What is Misconduct? \nThe following acts and omissions shall be treated as misconduct: \n1. Willful defiance or disobedience, whether alone or  in combination with others, to any \nlawful and reasonable order of a superior; \n2. Theft, fraud or dishonesty in connection with office business or property; \n3. Willful damage to or loss of the office goods or property; \n4. Using the position personally to obtain money or other valuables or to borrow funds; \n5. Habitual absence without leave or absence without leave for more than two (02) days; \n6. Habitual late attendance; \n7. Breach of any law applicable to the office; \n8. Riotous or disorderly behaviors during working hours at the office or any acts subversive \nof discipline; \n9. Habitual negligence or neglect of work; \n10. Tampering of official secrets; \n11. Strike, go-slow or inciting to do the same; \n12. Violating office rules and regulations including (Code of Conduct); \n13. Frequent repetition of any of the following acts or omissions: \ni. Disregard or disobedience of rules or orders; \nii. Improper behavior such as drunkenness and drugging; \niii. Making false or misleading statements; \niv. Inefficient, careless or wasteful working; \nv. Laziness; \nvi. Striking work or inciting othe rs to strike in contravention of the \nprovisions of any law or rule having the force of law; \nvii. Indulging in political, sectarian and or other extreme activities inside \nor beyond office hours; ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_17': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_17', embedding=None, metadata={'page_label': '18', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 18 of 35 \n \n \nviii. Indulging in use of drugs and or possession, sale, transfer etc., of drugs \nwhich means and includes liquor, heroin, hashish, opium etc. \n No order of immediate dismissal will  be made unless the employee concerned is informed in \nwriting of the alleged misconduct and is given an opportunity to explain the circumstances \nalleged against him/her within 24 hours after receiving the written order. \n \nWhere, for the purpose of conducting an inquiry into the alleged misconduct of any employee \nthe Management considers it necessary, the employee concerned may be suspended for a period \nnot exceeding three (3) days at a time. The order of suspension may be in writing and may take \neffect immediately on delivery to the employee. \n \n During the period of suspension, the employee concerned may be paid by the office subsistence \nallowance of not less than fifty per cent of his/her pay. If the employee is not found guilty, \nhe/she shall be deemed to have been on duty during the period of suspension and may be entitled \nto the same pay, as he/she would have received if he/she had not been suspended. \n \nAll the employees are expected and required to conduct themselves in a business -like manner \nwith ethics and obey all lawful orders and instructions. Whosoever fails  to observe the above \nshall be subject to disciplinary action. \n \nAll the employees are expect ed a nd required to observe “ Code of Conduct”, decided & \ncommunicated by the Management from time to time. \n 10.2 Punishments \nAn employee who fails to observe (General Discipline) mentioned above and found guilty of \nmisconduct may be liable to any of the following punishments: \ni. Issuance of warning letter: After three warnings, employee would be terminated \nfrom his position right away. \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_18': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\HiveWorx_HR_Policy_Manual.pdf_part_18', embedding=None, metadata={'page_label': '19', 'file_name': 'HiveWorx_HR_Policy_Manual.pdf', 'ceo': 'true', 'developer': 'true', 'manager': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='                                                                                            HR POLICY MANUAL     \nPage 19 of 35 \n \n \nii. Monitory Punishment: Fines will be imposed which could entail one-day salary \nto 1-month salary deduction. \niii. Withholding of increment for a specified period not exceeding one (1) year. \niv. Demotion or reduction in salary. \nv. Immediate Dismissal/ suspension without payment of any compensation in lieu \nof notice. \n  ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
# ...
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_126': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_126', embedding=None, metadata={'page_label': '127', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='102. The Order\n \nA couple from Ohio is on vacation in Miami. They are sitting at a beachside\nrestaurant and are ready to order. Finally, the waiter comes. He brings two\nmenu cards and then disappears. The couple looks at the menu and is not\nimpressed. There the man discovers dried-up Ketchup remains on the menu\nand shakes it with disgust. The waiter takes his time to serve other guests\nfirst and finally returns to the table with two glasses and water. He holds the\nglasses with his fingers on the edges, puts them on the table, and disappears\nagain. The woman says to her husband. “I can see his fingerprints on the\nglasses. That\'s disgusting. Can you tell the waiter to bring us two other\nglasses?”\n“But then the waiter wants to know why and we would have a serious\ndiscussion.”\n“Then ask him if he can bring us two closed water bottles.”\n“For that, we would need to pay extra. But I have an idea; I think we still\nhave water bottles in the car. I\'m going to get them.”\n“Good Idea. Please also bring the soap and a cloth so we can clean up the\ntable before the waiter returns."\n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_127': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_127', embedding=None, metadata={'page_label': '128', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='103. One Michelin Star is not Enough\n \nThe two brothers, Marc and Michael, are skilled restaurateurs, educated in a\nrestaurant school in Switzerland. Both have already worked in established\nFrench Restaurants, and also have built a good reputation.\nTen years ago, they opened their first restaurant in London. From the\nbeginning, the restaurant went well, and it took only a few years until the\nrestaurant was awarded its first Michelin Star. The restaurant becomes\nfamous, and not even two years later they receive a second Michelin Star.\nLast year, the brothers opened a second restaurant in another part of the city.\nA few months ago the big shock came. The brothers learned that their first\nrestaurant had only received one Michelin Star; the second star was denied\nfor unknown reasons.\nA friend who works for a restaurant magazine revealed to the brothers that\nthey got a star less, because they carried their soup in plastic bags from one\nrestaurant to the other.\nThe brothers were very upset. All they could do is try to improve the\nbusiness and also place new advertising. But somehow the information that\nthe restaurant was carrying soup outside in bags had leaked to the public.\nOne day they suddenly saw a sharp increase in their business. More orders\nthan expected came in; the customers came in to buy soup to take away.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_128': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_128', embedding=None, metadata={'page_label': '129', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Every day it seemed, more requests for soup followed.\nIt looked like the best selling dish were the soups now. The brothers are\nconvinced that negative news about the restaurant can be very good for\nbusiness. ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_129': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_129', embedding=None, metadata={'page_label': '130', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="104. The Allotment\n \nUnknown to many, German culture is also known for its allotments. Outside\nof the big cities, many people own small allotment plots which consist of a\nsmall garden and a small hut. Many of these allotments often form a small\ncolony.\nMost of the allotment owners are retirees and use it to escape from the inner\ncities.\nOne of these allotment owners is Wolfgang Meier, a pensioner from\nHamburg. In his garden, he has built a small pond. He is very proud of his\nlittle goldfish that are swimming in the pond. Actually, Mr. Meier has no\nfamily and loves his fish. Every fish he has given a name.\nOne day, Mr. Meier visits his allotment and discovers a few of the fish dead\non the surface. There's no explanation. Mr. Meier, however, is very sad and\ndecides to sell his allotment. Strangely, nobody wants to buy his plot.\nFortunately, a neighbor eventually buys his allotment for a very cheap price.\nThe neighbor is very happy with his plot and takes special care of it. After a\nshort time, the allotment is in great condition. The garden is blossoming,\nand the pond is full of fish.\nFrom time to time, Mr. Meier comes to visit his old allotment just to see\nwhat has changed. Mr. Meier is a bit jealous and he wishes to use his old", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_130': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_130', embedding=None, metadata={'page_label': '131', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='allotment again.\nOne day, unexpectedly many dead fish are in the pond again.\nA short time later, the new owner of the allotment receives a letter from Mr.\nMeier. It states that he, Mr. Meier would like to use the allotment on\nweekends. If he is allowed to use it for free, he would take care of the fish\nproblem and guarantee that no more fish will die. On the other hand, he\nstates that should his request be denied, he could imagine the problems\nbecoming worse.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_131': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_131', embedding=None, metadata={'page_label': '132', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='105. Inexpensive Shopping In Japan\n \nMy name is Rachel, and today I’m going to shop at the Japanese\nsupermarket. As a student in Japan, I do not have much money and\ntherefore must save on food. In addition, I support my mother in my home\ncountry. I mainly eat fish and vegetables. It’s my so-called sushi diet.\nLuckily, these items are relatively inexpensive to buy in Japan. In the\nmorning hours, the supermarkets are usually not as crowded. Today I need\nto buy rice, vegetables, tuna, and pasta. If I find something less expensive, I\nbuy more. I buy only a little, which I feel means something more for the\nJapanese.\n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_132': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_132', embedding=None, metadata={'page_label': '133', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='106. History - The First Humans\n \nMost scholars still agree that the "African origin" model holds that all or\nnearly all modern human genetic diversity around the world can be traced\nback to the first anatomically modern humans to leave Africa.\nThe first Homo sapiens came out of North-East Africa, approximately 70\nthousand years ago, and for at least 40,000 of those years, they obtained\nalmost all of their food sources by hunting and gathering.\nThis species then migrated out of Africa along a coastal route via the\nArabian Peninsula to South- and Southeast Asia, and eventually reached the\nPacific and Australia. About 50 thousand years ago, the first modern\nhumans, a subspecies of Homo sapiens, migrated from Africa to Asia\nMinor, and over the Caucasus to Europe; regarding the history of Modern\nhumans reached Central Europe about 40 thousand years ago. Humans also\nmigrated to the Americas about 15 thousand years ago; most came over the\nland-bridge which is now called the Bering Strait.\nThe 10th millennium BC saw the invention of agriculture and the beginning\nof the ancient era.\nThe Neolithic Age or New Stone Age was a period in the development of\nhuman technology, which included primitive tools beginning about 10,200\nBC. Hunter-gatherers of that time had access to goods and tools that', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_133': Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\100-English-Short-Stories.pdf_part_133', embedding=None, metadata={'page_label': '134', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'developer': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='prehistoric hunter-gatherers did not have, due to trade with neighboring\ntribes and early agrarian societies. Most modern hunter-gatherers could\nalready forge iron, making hunting and cutting tools of stones and bones\nwhich made primitive agriculture and hunting considerably easier.\n \n ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')}

# %%
len(doc_ids)
# Out:
# 0

# %%
docs = SimpleDirectoryReader(input_dir="C:/Users/Ds-Terminal/Desktop/rag-llamaindex-chroma/data/xyzz/new_files").load_data()

# %%
docs[5]
# Out:
# Document(id_='472c3797-7a2b-41fd-a304-7936199ff6c9', embedding=None, metadata={'page_label': '6', 'file_name': '100-English-Short-Stories.pdf', 'file_path': 'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\xyzz\\new_files\\100-English-Short-Stories.pdf', 'file_type': 'application/pdf', 'file_size': 2037873, 'creation_date': '2025-10-24', 'last_modified_date': '2025-10-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='47. Vegan Food\n48. Evacuation\n49. Working Men\n50. Under the Lamp Post\n51. My Best Friend\n52. Preparations\n53. Social Media\n54. Big Lenders Big Spenders\n55. Traffic And Kids\n56. Down with the Pounds\n57. Kindness\n58. A Helping Hand\n59. My Hobbies\n60. Vacation is Important\n61. Learning in a Group\n62. Our New House\n63. Studying Abroad\n64. The Circus\n65. The Car Accident\n66. Our Hotel\n67. In the Office\n68. A Walk in the Park\n69. A Special Credit\n70. Winning the Lottery\n71. The Application\n72. Taxi Driver\n73. In the Theater\n74. At the Bakery\n75. My old Drivers License\n76. Dialogue - Where is our Cat?\n77. The First Time in England\n78. A Happy Marriage\n79. School and Our Future Plans\n80. I Marry My Office\n81. Dialogue - Today we have Pigeon Meat\n82. The Hermit\n83. Retirement in Comfort\n84. The Barbecue Evening\n85. The Maid\n86. The Merchant of Arts\n87. A New World\n88. AirBnB The Mysterious Shadow and a Revolver\n89. Adventures in the Spa\n90. A Religious Family\n91. Crowdfunding for a new Kitchen\n92. How To Find a Millionaire on a Cruise Trip\n93. A Visit From America\n94. The Old Lush\n95. The Treasure in the Woods\n96. Au Pair in England', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')

# %%
from services.ingest_service import build_ingestion_pipeline
pipeline = build_ingestion_pipeline(vector_store = vector_store, doc_store = storage_context.docstore)

# %%
nodes = pipeline.run(docs)
# Out:
# Parsing nodes: 0it [00:00, ?it/s]

# %%
nodes
# Out:
# []

# %%
chroma_client = get_vector_db_client()

# %%
index = get_index(department="dep")
# Out:
# got collection already created.
# after initializing vector store
# before storage_context initialization
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep\docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep\index_store.json.
# storage_context from path
# before returning storage_context......................
# after getting storage context within get_index
# after index initialization in get_index

# %%
index.as_retriever().retrieve("tell me somthing about icd10")
# Out:
# [NodeWithScore(node=TextNode(id_='ab124a3f-751b-48c3-9acc-ea6d8a262015', embedding=None, metadata={'page_label': '1', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'developer': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'ceo', 'manager', 'developer', 'department'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'ceo', 'manager', 'developer', 'department'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_0', node_type='4', metadata={'page_label': '1', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'developer': 'true', 'department': 'dep'}, hash='5481973e6817b2aa6ba060630418d0b027ddaf7393424a0fa1eedca09374206c'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='2fa53456-a2dc-424a-a155-3618faa0cdb6', node_type='1', metadata={'page_label': '1', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'developer': 'true', 'department': 'dep'}, hash='2216597f5effb1ff4e74b03a287e35a87ecbf64b1baa1cac193d7e0436bbb3e8'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='01ea50ad-b71d-45f5-9cea-e5d36a3797fa', node_type='1', metadata={}, hash='bb35ca4f4f7922db7795ddab6e1c17f8de9d3fdb6157705eb78018ea0cd5b860')}, metadata_template='{key}: {value}', metadata_separator='\n', text='The ICD-\n10-CM is based on the ICD -10, the statistical classification of disease published by the World \nHealth Organization (WHO). \n \nThese guidelines have been  approved by the four organizations that make up the Cooperating \nParties for the ICD-10-CM: the American Hospital Association (AHA), the American Health \nInformation Management Association (AHIMA), CMS, and NCHS. \n \nThese guidelines are a set of rules that hav e been developed to accompany and complement the \nofficial conventions and instructions provided within the ICD -10-CM itself. The instructions and \nconventions of the classification take precedence over guidelines. These guidelines are based on \nthe coding and sequencing instructions in the Tabular List and Alphabetic Index of ICD-10-CM, \nbut provide additional instruction. Adherence to these guidelines when assigning ICD -10-CM \ndiagnosis codes is required under the Health Insurance Portability and Accountabilit y Act \n(HIPAA). The diagnosis codes ( Tabular List and Alphabetic Index ) have been adopted under \nHIPAA for all healthcare settings. A joint effort between the healthcare provider and the coder is \nessential to achieve complete and accurate documentation, code assignment, and reporting of \ndiagnoses and procedures.', mimetype='text/plain', start_char_idx=987, end_char_idx=2249, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7673466363696827),
#  NodeWithScore(node=TextNode(id_='7e18e349-f900-4a93-9697-41388fe1c974', embedding=None, metadata={'page_label': '111', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'developer': 'true', 'department': 'dep'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'ceo', 'manager', 'developer', 'department'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'ceo', 'manager', 'developer', 'department'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_110', node_type='4', metadata={'page_label': '111', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'developer': 'true', 'department': 'dep'}, hash='12c2dc8fb3ed78c1c60e60c47309b9182552cccfb5e40ec77baa4665cc4e755f'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='b931694e-bc13-46e8-858e-d9c613dd8598', node_type='1', metadata={'page_label': '111', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'developer': 'true', 'department': 'dep'}, hash='cf3721b9d35b0141554d9787196995ec6f036570b1c9f79fb338c42ea8052f75'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='33321d2e-7499-40e5-b565-2fa0d234a03f', node_type='1', metadata={}, hash='333fdda29e2f5488150a789c4dda3e470b9375f5a1613ee188e35434e03c6930')}, metadata_template='{key}: {value}', metadata_separator='\n', text='C. Accurate reporting of ICD-10-CM diagnosis codes \nFor accurate reporting of ICD-10-CM diagnosis codes, the documentation should describe the \npatient’s condition, using terminology which includes specific diagnoses as well as symptoms, \nproblems, or reasons for the encounter. There are ICD-10-CM codes to describe all of these. \nD. Codes that describe symptoms and signs \nCodes that describe symptoms and signs, as opposed to diagnoses, are acceptable for reporting \npurposes when a diagnosis has not been established (confirmed) by the provider. Chapter 18 of \nICD-10-CM, Symptoms, Signs, and Abnormal Clinical and Laboratory Findings Not Elsewhere \nClassified (codes R00-R99) contain many, but not all codes for symptoms. \nE. Encounters for circumstances other than a disease or injury \nICD-10-CM provides codes to deal with encounters for circumstances other than a disease or \ninjury. The Factors Influencing Health Status and Contact with Health Services codes (Z00-\nZ99) are provided to deal with occasions when circumstances other than a disease or injury are \nrecorded as diagnosis or problems. \nSee Section I.C.21. Factors influencing health status and contact with health services. \nF. Level of Detail in Coding \n1.', mimetype='text/plain', start_char_idx=1221, end_char_idx=2449, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7341155584496868)]

# %%
llm.complete("hello")
# Out:
# CompletionResponse(text="Hello! It's great to hear from you. Is there something I can help you with today? Do you have a question, need some information, or just want to chat? I'm here to assist you in any way I can.", additional_kwargs={'tool_calls': [], 'thinking': None}, raw={'model': 'koesn/llama3-8b-instruct:latest', 'created_at': '2025-10-27T17:53:23.944372106Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1940409614, 'load_duration': 32050047, 'prompt_eval_count': 45, 'prompt_eval_duration': 83276345, 'eval_count': 49, 'eval_duration': 1823455699, 'message': Message(role='assistant', content="Hello! It's great to hear from you. Is there something I can help you with today? Do you have a question, need some information, or just want to chat? I'm here to assist you in any way I can.", thinking=None, images=None, tool_name=None, tool_calls=None), 'usage': {'prompt_tokens': 45, 'completion_tokens': 49, 'total_tokens': 94}}, logprobs=None, delta=None)

# %%
chroma_client = get_vector_db_client()

# %%
chroma_client.delete_collection("dep")

# %%
chroma_client.list_collections()
# Out:
# [Collection(name=dep)]

# %%
# Out:
# ---------------------------------------------------------------------------
# AuthorizationError                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 chroma_client.reset()
#
# File c:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\.venv\Lib\site-packages\chromadb\api\client.py:438, in Client.reset(self)
#     436 @override
#     437 def reset(self) -> bool:
# --> 438     return self._server.reset()
#
# File c:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\.venv\Lib\site-packages\chromadb\api\rust.py:572, in RustBindingsAPI.reset(self)
#     570 @override
#     571 def reset(self) -> bool:
# --> 572     return self.bindings.reset()
#
# AuthorizationError: Reset is disabled by config

# %%
index_struct = storage_context.index_store.index_structs()[1]

# %%
collection = chroma_client.get_collection("xyzz")
vector_store = ChromaVectorStore(chroma_collection=collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store, persist_dir=STORAGE_PATH)
# index = VectorStoreIndex.from_vector_store(vector_store=vector_store, storage_context = storage_context)
# index = VectorStoreIndex(storage_context=storage_context, index_struct = index_struct)
# index = load_index_from_storage(storage_context=storage_context, index_id="2b0a1a82-6c8c-4b5d-b4cf-6493875dd6cf")
# Out:
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\index_store.json.

# %%
index = load_index_from_storage(storage_context=storage_context)

# %%
index = VectorStoreIndex.from_vector_store(vector_store=vector_store)

# %%
index = get_index(department="xyzz")
# Out:
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\index_store.json.

# %%
index_struct = storage_context.index_store.index_structs()

# %%
index_struct
# Out:
# [IndexDict(index_id='2b0a1a82-6c8c-4b5d-b4cf-6493875dd6cf', summary=None, nodes_dict={}, doc_id_dict={}, embeddings_dict={})]

# %%
storage_context.index_store.delete_index_struct(index_struct[0].index_id)

# %%
storage_context.persist()

# %%
retriever = index.as_retriever()
retriever.retrieve("something about computer science.")
# Out:
# [NodeWithScore(node=TextNode(id_='8a5f0bb5-b130-41f7-b62b-49705778d094', embedding=None, metadata={'page_label': '26', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'department': 'xyzz'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'ceo', 'manager', 'developer', 'department'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'ceo', 'manager', 'developer', 'department'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\xyzz\\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_25', node_type='4', metadata={'page_label': '26', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'department': 'xyzz'}, hash='fe2cfa11d51545472bd8c8127aadb02a71157eea9738bd9d9e94f9ad787258ad'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='6fc52024-814f-42b6-a501-2dfe159a3bcc', node_type='1', metadata={'page_label': '26', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'department': 'xyzz'}, hash='d61a99dbe8bef67010e6fe8e60fa3e854a41060e394c7fdf0286b37536286e3c')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Do not assign a code from \nsubcategory Z16.11, Resistance to penicillins. \n(c) Methicillin susceptible Staphylococcus aureus (MSSA) and \nMRSA colonization \nThe condition or state of being colonized or carrying MSSA or \nMRSA is called colonization or carriage, while an individual \nperson is described as being colonized or being a carrier.', mimetype='text/plain', start_char_idx=1957, end_char_idx=2296, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.6216212900589009),
#  NodeWithScore(node=TextNode(id_='ec503455-85d8-4f1d-8e2e-9e0c615e6dff', embedding=None, metadata={'page_label': '87', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'department': 'xyzz'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'ceo', 'manager', 'developer', 'department'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date', 'ceo', 'manager', 'developer', 'department'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\xyzz\\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_86', node_type='4', metadata={'page_label': '87', 'file_name': 'ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf', 'ceo': 'true', 'department': 'xyzz'}, hash='3cc4bf664e938d211ab084c72867273da9233e5dbbb2d8d42fc23479c2794974'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='996adc7f-bc32-4e36-991f-4b5696bcbf1d', node_type='1', metadata={}, hash='34d84825891ed414c861900e83500bcb345d453264c424379112a933d3b1aa04')}, metadata_template='{key}: {value}', metadata_separator='\n', text='ICD-10-CM Official Guidelines for Coding and Reporting \nFY 2025 \nPage 87 of 120 \n \n4) Assign as many external cause codes as necessary \nAssign as many external cause codes as necessary to fully explain each \ncause. If only one external code can be recorded, assign the code most \nrelated to the principal diagnosis. \n5) The selection of the appropriate external cause code \nThe selection of the appropriate external cause code is guided by the \nAlphabetic Index of External Causes and by Inclusion and Exclusion \nnotes in the Tabular List. \n6) External cause code can never be a principal diagnosis \nAn external cause code can never be a principal (first-listed) diagnosis. \n7) Combination external cause codes \nCertain of the external cause codes are combination codes that identify \nsequential events that result in an injury, such as a fall which results in \nstriking against an object. The injury may be due to either event or both. \nThe combination external cause code used should correspond to the \nsequence of events regardless of which caused the most serious injury.', mimetype='text/plain', start_char_idx=0, end_char_idx=1075, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.6194751632005888)]

# %%
results = collection.get(
    where={"file_name": "computer science.pdf"},
    include=["metadatas"] # Request to include the metadata of the matching segments
).get("metadatas")

# %%
results[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 results[0]
#
# IndexError: list index out of range

# %%
for key , value in results.items():
    print(key)
# Out:
# ids
# embeddings
# documents
# uris
# included
# data
# metadatas

# %%
metadatas = results.get("metadatas")

# %%
results.get("metadatas")[0]
# Out:
# {'file_name': 'computer science.pdf',
#  'doc_id': 'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\xyzz\\computer science.pdf_part_0',
#  'page_label': '1',
#  '_node_type': 'TextNode',
#  'document_id': 'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\xyzz\\computer science.pdf_part_0',
#  'department': 'xyzz',
#  '_node_content': '{"id_": "0f8e09ed-c9d1-4af2-9802-f087fcda0a2e", "embedding": null, "metadata": {"page_label": "1", "file_name": "computer science.pdf", "ceo": "true", "department": "xyzz"}, "excluded_embed_metadata_keys": ["file_name", "file_type", "file_size", "creation_date", "last_modified_date", "last_accessed_date", "ceo", "manager", "developer", "department"], "excluded_llm_metadata_keys": ["file_name", "file_type", "file_size", "creation_date", "last_modified_date", "last_accessed_date", "ceo", "manager", "developer", "department"], "relationships": {"1": {"node_id": "C:\\\\Users\\\\Ds-Terminal\\\\Desktop\\\\rag-llamaindex-chroma\\\\data\\\\xyzz\\\\computer science.pdf_part_0", "node_type": "4", "metadata": {"page_label": "1", "file_name": "computer science.pdf", "ceo": "true", "department": "xyzz"}, "hash": "eaecddc4e27ccaee59a03633108864c11636d1780006380b5b94e9223980373e", "class_name": "RelatedNodeInfo"}}, "metadata_template": "{key}: {value}", "metadata_separator": "\\n", "text": "", "mimetype": "text/plain", "start_char_idx": 0, "end_char_idx": 209, "metadata_seperator": "\\n", "text_template": "{metadata_str}\\n\\n{content}", "class_name": "TextNode"}',
#  'ceo': 'true',
#  'ref_doc_id': 'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\xyzz\\computer science.pdf_part_0'}

# %%
ref_doc_ids =[]
for metadata in results:
    ref_doc_ids.append(metadata.get("ref_doc_id"))

# %%
ref_doc_idx = {metadata.get("ref_doc_id") for metadata in results}

# %%
ref_doc_ids[0]
# Out:
# 'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\xyzz\\ICD-10-CM FY25 Guidelines October 1, 2024 (1).pdf_part_0'

# %%
for id in ref_doc_ids:
    index.delete_ref_doc(id, delete_from_docstore=True)

# %%
storage_context.persist(persist_dir = STORAGE_PATH)

# %%
client = get_vector_db_client()
collection = client.get_collection("dep")
metadatas = collection.get(
where={"file_name": "computer science.pdf"},
include=["metadatas"] 
).get("metadatas")

ref_doc_idx = [metadata.get("doc_id") for metadata in metadatas]

# %%
ref_doc_idx[0]
# Out:
# 'C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\dep\\computer science.pdf_part_0'

# %%
#######################working upto here ###########################

# %%
from services.get_index_service import get_storage_context

# %%
storage_context = get_storage_context("dep")
# Out:
# got collection already created.
# after initializing vector store
# before storage_context initialization
# from withing the create or get storage path:dep
# C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep
# from withing the create or get storage path:dep
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep\docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\storage\dep\index_store.json.
# storage_context from path
# before returning storage_context......................

# %%
docstore = storage_context.docstore
vectorstore = storage_context.vector_store

# %%
documents = docstore.docs.items()

# %%
docstore.delete_document(doc_id=ref_doc_idx[1],raise_error=True)

# %%
docstore.get_document(doc_id=ref_doc_idx[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 docstore.get_document(doc_id=ref_doc_idx[1])
#
# File c:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\.venv\Lib\site-packages\llama_index\core\storage\docstore\keyval_docstore.py:364, in KVDocumentStore.get_document(self, doc_id, raise_error)
#     362 if json is None:
#     363     if raise_error:
# --> 364         raise ValueError(f"doc_id {doc_id} not found.")
#     365     else:
#     366         return None
#
# ValueError: doc_id C:\Users\Ds-Terminal\Desktop\rag-llamaindex-chroma\data\dep\computer science.pdf_part_1 not found.

# %%
docs = []
for doc_id, doc in docstore.docs.items():
    if doc.metadata["file_name"] =="computer science.pdf":
        docs.append(doc)

# %%
len(docs)
# Out:
# 86

# %%
for doc in docs:
    docstore.delete_document(doc.id_)

# %%
storage_context.persist()

# %%
doc_id = doc.id_

# %%
doc_ref_id = doc.ref_doc_id

# %%
docstore.get_document(doc_id)
# Out:
# Document(id_='C:\\Users\\Ds-Terminal\\Desktop\\rag-llamaindex-chroma\\data\\comp\\100-English-Short-Stories.pdf_part_1', embedding=None, metadata={'page_label': '2', 'file_name': '100-English-Short-Stories.pdf', 'ceo': 'true', 'manager': 'true', 'department': 'comp'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=None, image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')

# %%
index.delete_ref_doc(doc_id, delete_from_docstore=True)

# %%
item = collection.get(doc.id_)

# %%
item.items()
# Out:
# dict_items([('ids', []), ('embeddings', None), ('documents', []), ('uris', None), ('included', ['metadatas', 'documents']), ('data', None), ('metadatas', [])])

# %%
index.delete(doc_id,delete_from_docstore=True)
# Out:
# WARNING:llama_index.core.indices.base:delete() is now deprecated, please refer to delete_ref_doc() to delete ingested documents+nodes or delete_nodes to delete a list of nodes.Use adelete_ref_docs() for an asynchronous implementation

# %%
ref_doc_id = doc.ref_doc_id
ref_doc_id

# %%
print(ref_doc_id)
# Out:
# None

# %%
storage_context.persist()
